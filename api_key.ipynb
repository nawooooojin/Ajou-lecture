# %%
import os
import openai

openai.api_key = os.environ["OPENAI_API_KEY"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 4
#       1 import os
#       2 import openai
# ----> 4 openai.api_key = os.environ["OPENAI_API_KEY"]
#
# File d:\Anaconda3_envs\gripul\lib\os.py:680, in _Environ.__getitem__(self, key)
#     677     value = self._data[self.encodekey(key)]
#     678 except KeyError:
#     679     # raise KeyError with the original key value
# --> 680     raise KeyError(key) from None
#     681 return self.decodevalue(value)
#
# KeyError: 'OPENAI_API_KEY'
